# %%
# !pip install numpy
# !pip install tqdm
# !pip install torch 
# !pip install matplotlib
# !pip install netwulf
# !pip install networkx
# !pip install pandas
# !pip install scikit-learn
# !pip install scipy
# !pip install seaborn
# !pip install torchvision
# !pip install ipywidgets
# Out:
# Requirement already satisfied: numpy in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (1.24.3)
# Requirement already satisfied: tqdm in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (4.65.0)
# Requirement already satisfied: matplotlib in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: netwulf in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (0.1.5)
# Requirement already satisfied: networkx>=2.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from netwulf) (3.1)
# Requirement already satisfied: numpy>=0.14 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from netwulf) (1.24.3)
# Requirement already satisfied: matplotlib>=3.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from netwulf) (3.7.1)
# Requirement already satisfied: simplejson>=3.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from netwulf) (3.19.1)
# Requirement already satisfied: contourpy>=1.0.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->netwulf) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->netwulf) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->netwulf) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->netwulf) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->netwulf) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->netwulf) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->netwulf) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->netwulf) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->netwulf) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0->netwulf) (3.15.0)
# Requirement already satisfied: six>=1.5 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->netwulf) (1.16.0)
# Requirement already satisfied: networkx in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (3.1)
# Requirement already satisfied: pandas in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting sklearn
#   Using cached sklearn-0.0.post5.tar.gz (3.7 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#
#       If the previous advice does not cover your use case, feel free to report it at
#       https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: scipy in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from scipy) (1.24.3)
# Requirement already satisfied: seaborn in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.15.0)
# Requirement already satisfied: six>=1.5 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Requirement already satisfied: torchvision in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (0.15.2)
# Requirement already satisfied: numpy in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: requests in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch==2.0.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: filelock in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (3.12.0)
# Requirement already satisfied: typing-extensions in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (4.6.3)
# Requirement already satisfied: sympy in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (1.12)
# Requirement already satisfied: networkx in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (2.0.0)
# Requirement already satisfied: setuptools in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (58.1.0)
# Requirement already satisfied: wheel in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (0.40.0)
# Requirement already satisfied: cmake in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (3.26.3)
# Requirement already satisfied: lit in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (16.0.5.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from requests->torchvision) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from requests->torchvision) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from jinja2->torch==2.0.1->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)
# Requirement already satisfied: ipywidgets in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (8.0.6)
# Requirement already satisfied: ipykernel>=4.5.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipywidgets) (6.23.1)
# Requirement already satisfied: ipython>=6.1.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipywidgets) (8.14.0)
# Requirement already satisfied: traitlets>=4.3.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipywidgets) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipywidgets) (3.0.7)
# Requirement already satisfied: comm>=0.1.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: packaging in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.1)
# Requirement already satisfied: psutil in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.2)
# Requirement already satisfied: backcall in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: pickleshare in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: typing-extensions in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (4.6.3)
# Requirement already satisfied: pexpect>4.3 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (6.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /zhome/a7/d/156506/myfolder/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (3.15.0)

# %%
import numpy as np
from tqdm.notebook import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
